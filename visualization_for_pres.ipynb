# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Activation functions

def relu(x: np.ndarray) -> np.ndarray:
    y = x.copy()
    y[y <= 0] = 0
    return y

def sigmoid(x: np.ndarray) -> np.ndarray:
    return 1 / (1 + np.exp(-x))

def tanh(x: np.ndarray) -> np.ndarray:
    return np.tanh(x) # same as np.tanh(x)

# %%
x = np.arange(-2, 2, step=0.05)
plt.figure(figsize=(7, 7))
plt.plot(x, x, label='Identity')
plt.plot(x, relu(x), label='ReLU')
plt.plot(x, sigmoid(x), label='Sigmoid')
plt.plot(x, tanh(x), label='Tanh')


plt.grid(True)
plt.legend()
plt.show()

# %%
x = np.array([3, 2, 4, 5]) # n * 1
W = np.random(size=(4, 1)) # n * k
z = W.T @ x # выход нашего линейного слоя

plt.figure(figsize=(7, 7))
plt.plot(z, z)
plt.plot(z, relu(z))
plt.plot(z, sigmoid(z))
plt.plot(z, tanh(z))

plt.legend()
plt.title('Выход нейронной сети и резличные функции активации')
